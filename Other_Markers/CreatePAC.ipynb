# %%
#R-code to include the PAC score in our analyses
library('data.table')
library('dplyr')
library('impute')
source("pac_proteomic_age.R")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
#Get eids set 3
set3_eids <- fread('Data/Processed/Full/full_test_eids.csv', data.table = FALSE)

#Proteomics data
allprots3000 <- fread('Data/Olink_UKBB_3000prots/Olink3000_Instance0.csv', data.table = FALSE)
ourset = fread('proteins_UKBB_imputed.csv', data.table=FALSE)

#Impute following the approach of https://doi.org/10.1111/acel.14195
rownames(allprots3000) <- allprots3000$eid
proteins_to_impute <- select(allprots3000, -c(eid, glipr1, npm1, pcolce))  # Remove eid and columns not to be imputed according to Kuo et al.
imputed_data <- impute.knn(as.matrix(proteins_to_impute), k = 10, rowmax = 0.5, colmax = 0.8, maxp = 1500, rng.seed = 7)$data
imputed_data <- as.data.frame(imputed_data)
imputed_data$eid <- rownames(imputed_data)  # Bring back eid for joining

# Reorder columns
allprots3000_imputed <- imputed_data[, c("eid", setdiff(names(imputed_data), "eid"))]

# Keep Set 3
allprots3000_set3 <- subset(allprots3000_imputed, eid %in% set3_eids$V1)

# Age
basic_info <- fread('Data/basicinfo_instance_0.csv', data.table = FALSE) %>%
  select(eid, age_center.0.0) %>%
  mutate(eid = as.character(eid)) %>%
  rename(age = age_center.0.0)

# Combine 
allprots3000_set3 <- left_join(allprots3000_set3, basic_info, by = "eid")
# Out:
# Warning message in knnimp(x, k, maxmiss = rowmax, maxp = maxp):
# “4286 rows with more than 50 % entries missing;
#  mean imputation used for these rows”
# Cluster size 48727 broken into 24214 24513
# Cluster size 24214 broken into 13480 10734
# Cluster size 13480 broken into 528 12952
# Done cluster 528
# Cluster size 12952 broken into 5768 7184
# Cluster size 5768 broken into 3366 2402
# Cluster size 3366 broken into 145 3221
# Done cluster 145
# Cluster size 3221 broken into 2087 1134
# Cluster size 2087 broken into 873 1214
# Done cluster 873
# Done cluster 1214
# Done cluster 2087
# Done cluster 1134
# Done cluster 3221
# Done cluster 3366
# Cluster size 2402 broken into 1793 609
# Cluster size 1793 broken into 309 1484
# Done cluster 309
# Done cluster 1484
# Done cluster 1793
# Done cluster 609
# Done cluster 2402
# Done cluster 5768
# Cluster size 7184 broken into 3698 3486
# Cluster size 3698 broken into 1321 2377
# Done cluster 1321
# Cluster size 2377 broken into 457 1920
# Done cluster 457
# Cluster size 1920 broken into 1323 597
# Done cluster 1323
# Done cluster 597
# Done cluster 1920
# Done cluster 2377
# Done cluster 3698
# Cluster size 3486 broken into 1764 1722
# Cluster size 1764 broken into 767 997
# Done cluster 767
# Done cluster 997
# Done cluster 1764
# Cluster size 1722 broken into 728 994
# Done cluster 728
# Done cluster 994
# Done cluster 1722
# Done cluster 3486
# Done cluster 7184
# Done cluster 12952
# Done cluster 13480
# Cluster size 10734 broken into 6198 4536
# Cluster size 6198 broken into 4074 2124
# Cluster size 4074 broken into 2039 2035
# Cluster size 2039 broken into 1108 931
# Done cluster 1108
# Done cluster 931
# Done cluster 2039
# Cluster size 2035 broken into 728 1307
# Done cluster 728
# Done cluster 1307
# Done cluster 2035
# Done cluster 4074
# Cluster size 2124 broken into 2014 110
# Cluster size 2014 broken into 1322 692
# Done cluster 1322
# Done cluster 692
# Done cluster 2014
# Done cluster 110
# Done cluster 2124
# Done cluster 6198
# Cluster size 4536 broken into 1214 3322
# Done cluster 1214
# Cluster size 3322 broken into 152 3170
# Done cluster 152
# Cluster size 3170 broken into 1782 1388
# Cluster size 1782 broken into 587 1195
# Done cluster 587
# Done cluster 1195
# Done cluster 1782
# Done cluster 1388
# Done cluster 3170
# Done cluster 3322
# Done cluster 4536
# Done cluster 10734
# Done cluster 24214
# Cluster size 24513 broken into 16409 8104
# Cluster size 16409 broken into 10133 6276
# Cluster size 10133 broken into 4243 5890
# Cluster size 4243 broken into 1807 2436
# Cluster size 1807 broken into 833 974
# Done cluster 833
# Done cluster 974
# Done cluster 1807
# Cluster size 2436 broken into 1297 1139
# Done cluster 1297
# Done cluster 1139
# Done cluster 2436
# Done cluster 4243
# Cluster size 5890 broken into 3262 2628
# Cluster size 3262 broken into 3 3259
# Done cluster 3
# Cluster size 3259 broken into 2081 1178
# Cluster size 2081 broken into 1411 670
# Done cluster 1411
# Done cluster 670
# Done cluster 2081
# Done cluster 1178
# Done cluster 3259
# Done cluster 3262
# Cluster size 2628 broken into 1476 1152
# Done cluster 1476
# Done cluster 1152
# Done cluster 2628
# Done cluster 5890
# Done cluster 10133
# Cluster size 6276 broken into 3863 2413
# Cluster size 3863 broken into 1062 2801
# Done cluster 1062
# Cluster size 2801 broken into 1281 1520
# Done cluster 1281
# Cluster size 1520 broken into 1328 192
# Done cluster 1328
# Done cluster 192
# Done cluster 1520
# Done cluster 2801
# Done cluster 3863
# Cluster size 2413 broken into 1196 1217
# Done cluster 1196
# Done cluster 1217
# Done cluster 2413
# Done cluster 6276
# Done cluster 16409
# Cluster size 8104 broken into 5866 2238
# Cluster size 5866 broken into 1681 4185
# Cluster size 1681 broken into 751 930
# Done cluster 751
# Done cluster 930
# Done cluster 1681
# Cluster size 4185 broken into 3917 268
# Cluster size 3917 broken into 2394 1523
# Cluster size 2394 broken into 730 1664
# Done cluster 730
# Cluster size 1664 broken into 1542 122
# Cluster size 1542 broken into 755 787
# Done cluster 755
# Done cluster 787
# Done cluster 1542
# Done cluster 122
# Done cluster 1664
# Done cluster 2394
# Cluster size 1523 broken into 980 543
# Done cluster 980
# Done cluster 543
# Done cluster 1523
# Done cluster 3917
# Done cluster 268
# Done cluster 4185
# Done cluster 5866
# Cluster size 2238 broken into 633 1605
# Done cluster 633
# Cluster size 1605 broken into 406 1199
# Done cluster 406
# Done cluster 1199
# Done cluster 1605
# Done cluster 2238
# Done cluster 8104
# Done cluster 24513

# %%
nrow(allprots3000_set3)
# Out:
# [1] 4068

# %%
pac_set3 = pac_proteomic_age(allprots3000_set3)
df_pac_set3 = cbind(allprots3000_set3[,"eid"], as.data.frame(pac_set3))
names(df_pac_set3) = c("eid", "PAC")
fwrite(df_pac_set3, 'Data/Other_Biomarkers/pac_set3.csv')

# %%
fwrite(allprots3000_set3, 'Data/Other_Biomarkers/proteins_set3_imputed_other_biomarkers.csv')
